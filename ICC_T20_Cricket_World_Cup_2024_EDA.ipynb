# %% [markdown]
# <a href="https://colab.research.google.com/github/GayanMSD/2024-T20-WC-EDA/blob/main/ICC_T20_Cricket_World_Cup_2024_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ICC T20 Cricket World Cup 2024 EDA**
#
# This work book is a explortary data analysis of the Last T20 World Cup which was held in 2024 in USA and West Indies.

# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Dataset
#
# ICC Mens T20 World Cup 2024 Stats
#
# This dataset was extracted from Kaggle
#
# Url For the Dataset: https://www.kaggle.com/datasets/kamalisrani/mens-t20-cwc-dataset-2007-2004
#
# > This dataset contains detailed statistics from the ICC Men's T20 World Cup 2024. It includes match results, batting statistics of all players, and bowling statistics of all players. The data is structured to facilitate in-depth analysis of team performances, individual player contributions, and overall tournament trends.

# %% [markdown]
# ### Importing the Dataset

# %%
t20_wc_2024_batting = pd.read_csv('/content/drive/MyDrive/data/icc-mens-t20-world-cup-2024-stats/batting_stats_for_icc_mens_t20_world_cup_2024.csv')
t20_wc_2024_bowling = pd.read_csv('/content/drive/MyDrive/data/icc-mens-t20-world-cup-2024-stats/bowling_stats_for_icc_mens_t20_world_cup_2024.csv')
t20_wc_2024_fielding = pd.read_csv('/content/drive/MyDrive/data/icc-mens-t20-world-cup-2024-stats/fielding_stats_for_icc_mens_t20_world_cup_2024.csv')
t20_wc_2024_match_results = pd.read_csv('/content/drive/MyDrive/data/icc-mens-t20-world-cup-2024-stats/match_results_for_icc_mens_t20_world_cup_2024.csv')

# %%
#Data Cleaning and Preprocessing¶
t20_wc_2024_match_results['Match Date'] = pd.to_datetime(t20_wc_2024_match_results['Match Date'])

# %% [markdown]
# ## Batting Analysis
#
# ---

# %% [markdown]
# ### Data Summary

# %%
t20_wc_2024_batting.head()
# Out:
#          Player                      Team  Mat  Inns  NO  Runs   HS   Ave  \
# 0    NP Kenjige  United States of America    4     2   0     1    1   0.5
# 1   Aaron Jones  United States of America    6     6   2   162  94*  40.5
# 2  Aasif Sheikh                     Nepal    3     3   0    63   42  21.0
# 3  Abbas Afridi                  Pakistan    1     1   0    17   17  17.0
# 4     F Achelam                    Uganda    1     1   0     9    9   9.0
#
#        SR  100  50  0
# 0   25.00    0   0  1
# 1  135.00    0   1  1
# 2   88.73    0   0  0
# 3   80.95    0   0  0
# 4   69.23    0   0  0

# %%
t20_wc_2024_batting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  247 non-null    object
#  1   Team    247 non-null    object
#  2   Mat     247 non-null    int64
#  3   Inns    247 non-null    int64
#  4   NO      247 non-null    int64
#  5   Runs    247 non-null    int64
#  6   HS      247 non-null    object
#  7   Ave     247 non-null    float64
#  8   SR      247 non-null    float64
#  9   100     247 non-null    int64
#  10  50      247 non-null    int64
#  11  0       247 non-null    int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 23.3+ KB

# %% [markdown]
# ### Top Run Scorers

# %%
top_run_scorers = t20_wc_2024_batting.sort_values(by="Runs", ascending=False).head(10)
display(top_run_scorers)
# Out:
#                  Player                      Team  Mat  Inns  NO  Runs   HS  \
# 179  Rahmanullah Gurbaz               Afghanistan    8     8   0   281   80
# 202           RG Sharma                     India    8     8   1   257   92
# 75              TM Head                 Australia    7     7   1   255   76
# 47            Q de Kock              South Africa    9     9   0   243   74
# 82       Ibrahim Zadran               Afghanistan    8     8   0   231   70
# 173            N Pooran               West Indies    7     7   1   228   98
# 65             AGS Gous  United States of America    6     6   1   219  80*
# 36           JC Buttler                   England    8     7   2   214  83*
# 244            SA Yadav                     India    8     8   1   199   53
# 105           H Klaasen              South Africa    9     8   2   190   52
#
#        Ave      SR  100  50  0
# 179  35.12  124.33    0   3  2
# 202  36.71  156.70    0   3  0
# 75   42.50  158.38    0   2  1
# ...

# %% [markdown]
# ### Strike Rate Comparision

# %%
top_run_scorers.plot(x = 'Player', y = "SR", kind= "bar", figsize=(12,6))
plt.title("Strike Rate Comparision")

plt.show()

# %% [markdown]
# ### Top Run Scorers for World Cup Winners - India

# %%
top_run_scorers_india = t20_wc_2024_batting.loc[t20_wc_2024_batting["Team"] == "India"].sort_values(by="Runs", ascending=False).head(15)
display(top_run_scorers_india)
# Out:
#              Player   Team  Mat  Inns  NO  Runs   HS    Ave      SR  100  50  \
# 202       RG Sharma  India    8     8   1   257   92  36.71  156.70    0   3
# 244        SA Yadav  India    8     8   1   199   53  28.42  135.37    0   2
# 165         RR Pant  India    8     8   1   171   42  24.42  127.61    0   0
# 106         V Kohli  India    8     8   0   151   76  18.87  112.68    0   1
# 164       HH Pandya  India    8     6   3   144  50*  48.00  151.57    0   1
# 55           S Dube  India    8     8   2   133   34  22.16  114.65    0   0
# 167        AR Patel  India    8     5   1    92   47  23.00  139.39    0   0
# 86        RA Jadeja  India    8     5   2    35  17*  11.66  159.09    0   0
# 15   Arshdeep Singh  India    8     3   2    12    9  12.00   75.00    0   0
# 140  Mohammed Siraj  India    3     1   1     7   7*   0.00  100.00    0   0
# 35        JJ Bumrah  India    8     1   0     0    0   0.00    0.00    0   0
#
#      0
# 202  0
# 244  0
# 165  1
# 106  2
# ...

# %% [markdown]
# ### Indian Batsmen Contribution by Runs

# %%
plt.pie(top_run_scorers_india["Runs"], labels=top_run_scorers_india["Player"], autopct="%1.1f%%")
plt.title("Indian Players Contribution by Runs")
plt.show()

# %% [markdown]
# # Bowling Analysis
#
# ---

# %% [markdown]
# ### Data Summary

# %%
t20_wc_2024_bowling.head()
# Out:
#          Player                      Team  Mat  Inns  Balls  Mdns  Runs  Wkts  \
# 0    NP Kenjige  United States of America    4     4     60     0    89     3
# 1  Abbas Afridi                  Pakistan    1     1     18     0    31     0
# 2      MR Adair                   Ireland    3     3     72     0    74     3
# 3       AC Agar                 Australia    2     2     48     1    56     1
# 4      DS Airee                     Nepal    3     3     57     0    49     6
#
#       BBI    Ave   Econ   SR  5  10  Ct
# 0  30-Mar  29.66   8.90   20  0   0   0
# 1       -   0.00  10.33    -  0   0   0
# 2  23-Jan  24.66   6.16   24  0   0   1
# 3  Jan-39  56.00   7.00   48  0   0   1
# 4  21-Mar   8.16   5.15  9.5  0   0   3

# %% [markdown]
# ### Top Wicket Takers

# %%
top_wicket_takers = t20_wc_2024_bowling.sort_values(by="Wkts", ascending=False).head(10)
display(top_wicket_takers)
# Out:
#                Player          Team  Mat  Inns  Balls  Mdns  Runs  Wkts  \
# 11     Arshdeep Singh         India    8     8    180     0   215    17
# 39   Fazalhaq Farooqi   Afghanistan    8     8    152     0   160    17
# 23          JJ Bumrah         India    8     8    178     2   124    15
# 104          A Nortje  South Africa    9     9    210     0   201    15
# 116       Rashid Khan   Afghanistan    8     8    174     0   179    14
# 119    Rishad Hossain    Bangladesh    7     7    150     0   194    14
# 59          AS Joseph   West Indies    7     7    147     0   177    13
# 100     Naveen-ul-Haq   Afghanistan    8     8    160     0   160    13
# 113          K Rabada  South Africa    9     9    186     2   195    13
# 160           A Zampa     Australia    7     7    168     0   187    13
#
#         BBI    Ave  Econ    SR  5  10  Ct
# 11    9-Apr  12.64  7.16  10.5  0   0   3
# 39    9-May   9.41  6.31   8.9  1   0   1
# 23    7-Mar   8.26  4.17  11.8  0   0   2
# ...

# %% [markdown]
# ### Economy Rates

# %%
top_wicket_takers["SR"] = top_wicket_takers["SR"].astype(float)
top_wicket_takers.plot(x = 'Player', y = 'SR', kind= "bar", figsize=(12,6))
plt.title("Economy Rates")
plt.xlabel("Player")
plt.ylabel("Economy Rate")
plt.show()

# %% [markdown]
# ### Team India's Bowlers Contribution for the victory

# %%
team_india_bowlers = t20_wc_2024_bowling.loc[t20_wc_2024_bowling["Team"] == "India"].sort_values(by="Wkts", ascending=False).head(15)
display(team_india_bowlers)
# Out:
#              Player   Team  Mat  Inns  Balls  Mdns  Runs  Wkts     BBI  \
# 11   Arshdeep Singh  India    8     8    180     0   215    17   9-Apr
# 23        JJ Bumrah  India    8     8    178     2   124    15   7-Mar
# 106       HH Pandya  India    8     8    150     2   191    11  20-Mar
# 68    Kuldeep Yadav  India    5     5    120     0   139    10  19-Mar
# 108        AR Patel  India    8     8    132     1   173     9  23-Mar
# 55        RA Jadeja  India    8     7     84     0   106     1  20-Jan
# 91   Mohammed Siraj  India    3     3     66     0    57     1  13-Jan
# 33           S Dube  India    8     1      6     0    11     0       -
#
#         Ave   Econ    SR  5  10  Ct
# 11    12.64   7.16  10.5  0   0   3
# 23     8.26   4.17  11.8  0   0   2
# 106   17.36   7.64  13.6  0   0   2
# 68    13.90   6.95    12  0   0   2
# 108   19.22   7.86  14.6  0   0   4
# 55   106.00   7.57    84  0   0   3
# 91    57.00   5.18    66  0   0   2
# ...

# %%
plt.pie(team_india_bowlers["Wkts"], labels=team_india_bowlers["Player"], autopct="%1.1f%%")
plt.title("Team India's Bowlers Contribution for the victory")
plt.xlabel("Player")
plt.ylabel("Wickets")
plt.show()

# %% [markdown]
# # Matches Analysis

# %% [markdown]
# ### Data Summary

# %%
t20_wc_2024_match_results.head(100)
# Out:
#                       Team 1                    Team 2  \
# 0   United States of America                    Canada
# 1                West Indies          Papua New Guinea
# 2                    Namibia                      Oman
# 3               South Africa                 Sri Lanka
# 4                Afghanistan                    Uganda
# 5                    England                  Scotland
# 6                      Nepal               Netherlands
# 7                      India                   Ireland
# 8           Papua New Guinea                    Uganda
# 9                  Australia                      Oman
# 10  United States of America                  Pakistan
# 11                   Namibia                  Scotland
# 12                    Canada                   Ireland
# 13               Afghanistan               New Zealand
# 14                Bangladesh                 Sri Lanka
# 15               Netherlands              South Africa
# ...

# %% [markdown]
# ### Grounds and Matches

# %%
matches_ground = t20_wc_2024_match_results.groupby("Ground")["Ground"].count()
matches_ground.name = 'Match Count'
display(matches_ground)
# Out:
# Ground
# Bridgetown     9
# Dallas         4
# Gros Islet     6
# Kingstown      5
# Lauderhill     1
# New York       8
# North Sound    8
# Providence     6
# Tarouba        5
# Name: Match Count, dtype: int64

# %%
matches_ground.plot(kind="bar", figsize=(12,6))
plt.title("Grounds and Matches")
plt.show()

# %% [markdown]
# ### Teams win lost

# %%
def get_team_results(df):
  all_teams = pd.unique(df[["Team 1", "Team 2"]].values.ravel("K"))

  team_results = {}

  for team in all_teams:
    team_results[team] = {'Matches': 0, 'Wins': 0, "Losses": 0, "No Result": 0, "Ties": 0}

  for index, row in df.iterrows():
    team1 = row["Team 1"]
    team2 = row["Team 2"]
    winner = row["Winner"]

    if winner == "no result":
      team_results[team1]["Matches"] += 1
      team_results[team2]["Matches"] += 1
      team_results[team1]["No Result"] += 1
      team_results[team2]["No Result"] += 1
    elif winner == "tied":
      team_results[team1]["Matches"] += 1
      team_results[team2]["Matches"] += 1
      team_results[team1]["Ties"] += 1
      team_results[team2]["Ties"] += 1
    elif winner == team1:
      team_results[team1]["Matches"] += 1
      team_results[team2]["Matches"] += 1
      team_results[team1]["Wins"] += 1
      team_results[team2]["Losses"] += 1
    elif winner == team2:
      team_results[team1]["Matches"] += 1
      team_results[team2]["Matches"] += 1
      team_results[team2]["Wins"] += 1
      team_results[team1]["Losses"] += 1


  return team_results


team_results_list = pd.DataFrame.from_dict(get_team_results(t20_wc_2024_match_results))
team_results_list = team_results_list.transpose().sort_values(by="Wins", ascending=False)
display(team_results_list.head(20))
# Out:
#                           Matches  Wins  Losses  No Result  Ties
# South Africa                    9     8       1          0     0
# India                           8     8       0          0     0
# Afghanistan                     8     5       3          0     0
# Australia                       7     5       2          0     0
# West Indies                     7     5       2          0     0
# England                         8     4       3          1     0
# Bangladesh                      7     3       4          0     0
# Pakistan                        4     2       1          0     1
# New Zealand                     4     2       2          0     0
# Scotland                        4     2       1          1     0
# Uganda                          4     1       3          0     0
# Sri Lanka                       3     1       2          0     0
# United States of America        6     1       4          0     1
# ...

# %% [markdown]
# ### Matches won Batting First and Bowling First

# %%
won_batting_first = t20_wc_2024_match_results.loc[t20_wc_2024_match_results["Margin"].str.contains("runs")].shape[0]
won_batting_first
# Out:
# 24

# %%
won_bowling_first = t20_wc_2024_match_results.loc[t20_wc_2024_match_results["Margin"].str.contains("wickets")].shape[0]
won_bowling_first
# Out:
# 24

# %%
plt.pie([won_batting_first, won_bowling_first], labels=["Won Batting First", "Won Bowling First"], autopct="%1.1f%%")
plt.title("Matches won Batting First and Bowling First")
plt.show()
